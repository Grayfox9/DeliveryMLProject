# %% [markdown]
# # Proyecto Individual 02
#
# ## Preprocesamiento de datos

# %%
#Importamos las librerias para realizar los ajustes necesarios.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Leemos el archivo "E-Commerce_train.xlsx" con ayuda de pandas
E_train = pd.read_excel(r'C:\Users\Mimar\Desktop\P\2\Datathon\E-Commerce_train.xlsx')
E_train
# Out:
#         ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0        1               D           Flight                    4
# 1        2               F           Flight                    4
# 2        3               A           Flight                    2
# 3        4               B           Flight                    3
# 4        5               C           Flight                    2
# ...    ...             ...              ...                  ...
# 8994  8995               D             Ship                    3
# 8995  8996               F             Ship                    5
# 8996  8997               A             Ship                    4
# 8997  8998               B             Ship                    4
# 8998  8999               C             Ship                    5
#
#       Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                   2                  177                3
# 1                   5                  216                2
# 2                   2                  183                4
# 3                   3                  176                4
# 4                   2                  184                3
# ...               ...                  ...              ...
# 8994                1                  217                3
# 8995                3                  232                3
# 8996                5                  260                3
# 8997                2                  184                3
# 8998                4                  145                4
#
#      Product_importance Gender  Discount_offered  Weight_in_gms  \
# 0                   low      F                44           1233
# 1                   low      M                59           3088
# 2                   low      M                48           3374
# 3                medium      M                10           1177
# 4                medium      F                46           2484
# ...                 ...    ...               ...            ...
# 8994                low      F                 1           4177
# 8995             medium      M                 3           4526
# 8996             medium      F                 6           4221
# 8997             medium      F                 5           5931
# 8998                low      M                 4           4790
#
#       Reached.on.Time_Y.N
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 8994                    1
# 8995                    0
# 8996                    0
# 8997                    1
# 8998                    0
#
# [8999 rows x 12 columns]

# %%
#Buscamos en este dataframe si existen instancias duplicadas.
E_train[E_train.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Warehouse_block, Mode_of_Shipment, Customer_care_calls, Customer_rating, Cost_of_the_Product, Prior_purchases, Product_importance, Gender, Discount_offered, Weight_in_gms, Reached.on.Time_Y.N]
# Index: []

# %%
#Corroboramos la cantidad de datos duplicados
E_train.duplicated().sum()
# Out:
# 0

# %%
#Corroboramos, con alguna fila al azar de cuadro anterior.

E_train[E_train.ID == 333]
# Out:
#       ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 332  333               A             Ship                    3
#
#      Customer_rating  Cost_of_the_Product  Prior_purchases Product_importance  \
# 332                5                  215                3             medium
#
#     Gender  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 332      F                22           2585                    1

# %%
#Corroboramos los valores nulos
E_train.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
#Después de esto, corroboramos el tipo de datos para cada columna
E_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8999 entries, 0 to 8998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   8999 non-null   int64
#  1   Warehouse_block      8999 non-null   object
#  2   Mode_of_Shipment     8999 non-null   object
#  3   Customer_care_calls  8999 non-null   int64
#  4   Customer_rating      8999 non-null   int64
#  5   Cost_of_the_Product  8999 non-null   int64
#  6   Prior_purchases      8999 non-null   int64
#  7   Product_importance   8999 non-null   object
#  8   Gender               8999 non-null   object
#  9   Discount_offered     8999 non-null   int64
#  10  Weight_in_gms        8999 non-null   int64
#  11  Reached.on.Time_Y.N  8999 non-null   int64
# dtypes: int64(8), object(4)
# memory usage: 843.8+ KB

# %%
#Leemos los archivos xlsx en pandas

E_test = pd.read_excel(r'C:\Users\Mimar\Desktop\P\2\Datathon\E-Commerce_test.xlsx')
E_test
# Out:
#          ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0      9000               F             Ship                    5
# 1      9001               D             Ship                    5
# 2      9002               F             Ship                    3
# 3      9003               A             Ship                    5
# 4      9004               B             Ship                    4
# ...     ...             ...              ...                  ...
# 1995  10995               A             Ship                    4
# 1996  10996               B             Ship                    4
# 1997  10997               C             Ship                    5
# 1998  10998               F             Ship                    5
# 1999  10999               D             Ship                    2
#
#       Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                   1                  189                2
# 1                   3                  150                2
# 2                   3                  200                3
# 3                   1                  133                2
# 4                   2                  260                3
# ...               ...                  ...              ...
# 1995                1                  252                5
# 1996                1                  232                5
# 1997                4                  242                5
# 1998                2                  223                6
# 1999                5                  155                5
#
#      Product_importance Gender  Discount_offered  Weight_in_gms
# 0                medium      M                10           5248
# 1                  high      F                 9           4446
# 2                   low      M                 3           5739
# 3                medium      M                 1           4643
# 4                   low      M                 4           5504
# ...                 ...    ...               ...            ...
# 1995             medium      F                 1           1538
# 1996             medium      F                 6           1247
# 1997                low      F                 4           1155
# 1998             medium      M                 2           1210
# 1999                low      F                 6           1639
#
# [2000 rows x 11 columns]

# %%
#Buscamos en este dataframe si existen instancias duplicadas.
E_test[E_test.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Warehouse_block, Mode_of_Shipment, Customer_care_calls, Customer_rating, Cost_of_the_Product, Prior_purchases, Product_importance, Gender, Discount_offered, Weight_in_gms]
# Index: []

# %%
#Corroboramos, con alguna fila al azar de cuadro anterior.

E_test[E_test.ID == 222]
# Out:
# Empty DataFrame
# Columns: [ID, Warehouse_block, Mode_of_Shipment, Customer_care_calls, Customer_rating, Cost_of_the_Product, Prior_purchases, Product_importance, Gender, Discount_offered, Weight_in_gms]
# Index: []

# %%
#Corroboramos la cantidad de datos duplicados
E_test.duplicated().sum()
# Out:
# 0

# %%
#Corroboramos los valores nulos
E_test.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# dtype: int64

# %%
#Después de esto, corroboramos el tipo de datos para cada columna
E_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2000 non-null   int64
#  1   Warehouse_block      2000 non-null   object
#  2   Mode_of_Shipment     2000 non-null   object
#  3   Customer_care_calls  2000 non-null   int64
#  4   Customer_rating      2000 non-null   int64
#  5   Cost_of_the_Product  2000 non-null   int64
#  6   Prior_purchases      2000 non-null   int64
#  7   Product_importance   2000 non-null   object
#  8   Gender               2000 non-null   object
#  9   Discount_offered     2000 non-null   int64
#  10  Weight_in_gms        2000 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 172.0+ KB

# %% [markdown]
# ## Transformación de datos de tipo categóricos

# %%
#En la data tenemos datos de tipo categoricos, por lo que utilizaremos
#la librería de scikitlearn para aplicar algunas funciones, de preporcesamiento.
from sklearn.preprocessing import LabelEncoder

# %%
#Para el preprocesamiento de datos, utilizamos la funcion de LabelEncoder que nos permite
#catalogar las variables categoricas contenidas en las columnas en numeros.
#En este caso llamamos dicha funcion para reducir a numeros las columnas "Warehouse_block",
# "Mode_of_Shipment", "Product_importance" y "Gender".
encoder = LabelEncoder()
E_train['Warehouse_block'] = encoder.fit_transform(E_train['Warehouse_block'])
E_train['Mode_of_Shipment'] = encoder.fit_transform(E_train['Mode_of_Shipment'])
E_train['Product_importance'] = encoder.fit_transform(E_train['Product_importance'])
E_train['Gender'] = encoder.fit_transform(E_train['Gender'])

E_train.head()
# Out:
#    ID  Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0   1                3                 0                    4
# 1   2                4                 0                    4
# 2   3                0                 0                    2
# 3   4                1                 0                    3
# 4   5                2                 0                    2
#
#    Customer_rating  Cost_of_the_Product  Prior_purchases  Product_importance  \
# 0                2                  177                3                   1
# 1                5                  216                2                   1
# 2                2                  183                4                   1
# 3                3                  176                4                   2
# 4                2                  184                3                   2
#
#    Gender  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0       0                44           1233                    1
# 1       1                59           3088                    1
# 2       1                48           3374                    1
# 3       1                10           1177                    1
# 4       0                46           2484                    1

# %% [markdown]
# De modo que nos queda las variables de la siguiente forma:
# -Warehouse -> [0=A, 1=B, 2=C, 3=D, 4=E, 5=F]
# -Mode_of_shipment -> [0=Flight, 1=Road, 2=Ship]
# -Product_importance -> [0=high, 1=low, 2=med]
# -Gender -> [0=F,1=M]
#
#
# Esto nos permite realizar el modelaje de una manera mucho más sencilla.

# %%
E_train
# Out:
#         ID  Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0        1                3                 0                    4
# 1        2                4                 0                    4
# 2        3                0                 0                    2
# 3        4                1                 0                    3
# 4        5                2                 0                    2
# ...    ...              ...               ...                  ...
# 8994  8995                3                 2                    3
# 8995  8996                4                 2                    5
# 8996  8997                0                 2                    4
# 8997  8998                1                 2                    4
# 8998  8999                2                 2                    5
#
#       Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                   2                  177                3
# 1                   5                  216                2
# 2                   2                  183                4
# 3                   3                  176                4
# 4                   2                  184                3
# ...               ...                  ...              ...
# 8994                1                  217                3
# 8995                3                  232                3
# 8996                5                  260                3
# 8997                2                  184                3
# 8998                4                  145                4
#
#       Product_importance  Gender  Discount_offered  Weight_in_gms  \
# 0                      1       0                44           1233
# 1                      1       1                59           3088
# 2                      1       1                48           3374
# 3                      2       1                10           1177
# 4                      2       0                46           2484
# ...                  ...     ...               ...            ...
# 8994                   1       0                 1           4177
# 8995                   2       1                 3           4526
# 8996                   2       0                 6           4221
# 8997                   2       0                 5           5931
# 8998                   1       1                 4           4790
#
#       Reached.on.Time_Y.N
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 8994                    1
# 8995                    0
# 8996                    0
# 8997                    1
# 8998                    0
#
# [8999 rows x 12 columns]

# %%
#Para el preprocesamiento de datos, utilizamos la funcion de LabelEncoder que nos permite
#catalogar las variables categoricas contenidas en las columnas en numeros.
#En este caso llamamos dicha funcion para reducir a numeros las columnas "Warehouse_block",
# "Mode_of_Shipment", "Product_importance" y "Gender".
encoder = LabelEncoder()
E_test['Warehouse_block'] = encoder.fit_transform(E_test['Warehouse_block'])
E_test['Mode_of_Shipment'] = encoder.fit_transform(E_test['Mode_of_Shipment'])
E_test['Product_importance'] = encoder.fit_transform(E_test['Product_importance'])
E_test['Gender'] = encoder.fit_transform(E_test['Gender'])

E_test.head()
# Out:
#      ID  Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0  9000                4                 2                    5
# 1  9001                3                 2                    5
# 2  9002                4                 2                    3
# 3  9003                0                 2                    5
# 4  9004                1                 2                    4
#
#    Customer_rating  Cost_of_the_Product  Prior_purchases  Product_importance  \
# 0                1                  189                2                   2
# 1                3                  150                2                   0
# 2                3                  200                3                   1
# 3                1                  133                2                   2
# 4                2                  260                3                   1
#
#    Gender  Discount_offered  Weight_in_gms
# 0       1                10           5248
# 1       0                 9           4446
# 2       1                 3           5739
# 3       1                 1           4643
# 4       1                 4           5504

# %%
E_test
# Out:
#          ID  Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0      9000                4                 2                    5
# 1      9001                3                 2                    5
# 2      9002                4                 2                    3
# 3      9003                0                 2                    5
# 4      9004                1                 2                    4
# ...     ...              ...               ...                  ...
# 1995  10995                0                 2                    4
# 1996  10996                1                 2                    4
# 1997  10997                2                 2                    5
# 1998  10998                4                 2                    5
# 1999  10999                3                 2                    2
#
#       Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                   1                  189                2
# 1                   3                  150                2
# 2                   3                  200                3
# 3                   1                  133                2
# 4                   2                  260                3
# ...               ...                  ...              ...
# 1995                1                  252                5
# 1996                1                  232                5
# 1997                4                  242                5
# 1998                2                  223                6
# 1999                5                  155                5
#
#       Product_importance  Gender  Discount_offered  Weight_in_gms
# 0                      2       1                10           5248
# 1                      0       0                 9           4446
# 2                      1       1                 3           5739
# 3                      2       1                 1           4643
# 4                      1       1                 4           5504
# ...                  ...     ...               ...            ...
# 1995                   2       0                 1           1538
# 1996                   2       0                 6           1247
# 1997                   1       0                 4           1155
# 1998                   2       1                 2           1210
# 1999                   1       0                 6           1639
#
# [2000 rows x 11 columns]

# %%
#Revisamos la distribucion de la columa 'Reached.on.Time_Y.N'
E_train['Reached.on.Time_Y.N'].value_counts()
# Out:
# 1    5719
# 0    3280
# Name: Reached.on.Time_Y.N, dtype: int64

# %%
#Importamos la librería para poder segmentar nuestra informacion y Separamos nuestras variables a entrenar y a testear
from sklearn.model_selection import train_test_split


X = E_train.drop(columns='Reached.on.Time_Y.N', axis=1)
Y = E_train['Reached.on.Time_Y.N']

# %%
X
# Out:
#         ID  Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0        1                3                 0                    4
# 1        2                4                 0                    4
# 2        3                0                 0                    2
# 3        4                1                 0                    3
# 4        5                2                 0                    2
# ...    ...              ...               ...                  ...
# 8994  8995                3                 2                    3
# 8995  8996                4                 2                    5
# 8996  8997                0                 2                    4
# 8997  8998                1                 2                    4
# 8998  8999                2                 2                    5
#
#       Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                   2                  177                3
# 1                   5                  216                2
# 2                   2                  183                4
# 3                   3                  176                4
# 4                   2                  184                3
# ...               ...                  ...              ...
# 8994                1                  217                3
# 8995                3                  232                3
# 8996                5                  260                3
# 8997                2                  184                3
# 8998                4                  145                4
#
#       Product_importance  Gender  Discount_offered  Weight_in_gms
# 0                      1       0                44           1233
# 1                      1       1                59           3088
# 2                      1       1                48           3374
# 3                      2       1                10           1177
# 4                      2       0                46           2484
# ...                  ...     ...               ...            ...
# 8994                   1       0                 1           4177
# 8995                   2       1                 3           4526
# 8996                   2       0                 6           4221
# 8997                   2       0                 5           5931
# 8998                   1       1                 4           4790
#
# [8999 rows x 11 columns]

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 8994    1
# 8995    0
# 8996    0
# 8997    1
# 8998    0
# Name: Reached.on.Time_Y.N, Length: 8999, dtype: int64

# %%
#Separamos la data de entrenamiento y testeo
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, stratify=Y, random_state=7)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (8999, 11) (6299, 11) (2700, 11)

# %% [markdown]
# Ya con esto realizamos el análisis de los datos mediante correlación.

# %% [markdown]
# ## Análisis de los datos: correlación

# %%
#En el archivo test vemos que variables tienen correlacion unas con otras.
corr_df = data_train.corr(method='pearson')


plt.figure(figsize=(8,6))
sns.heatmap(corr_df, annot=True)
plt.show()

# %%
# Viendo esta correlación procedemos a designar nuestros valores para entrenamiento (train) 
# y prueba (test)

# %% [markdown]
# # Entrenando el modelo

# %% [markdown]
# ## Regresión lógistica

# %%
#Importamos la librería para usar el modelo de regresión linear
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score

# %%
model = LogisticRegression()

# %%
#Entrenando el modelo de Regresion logistica con la train data.
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Evaluacion del modelo

# %%
# Puntaje de precisión sobre la data de entrenamiento

X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print(training_data_accuracy)
# Out:
# 0.6820130179393554

# %%
# Puntaje de precisión sobre la data de testeo

X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print(test_data_accuracy)
# Out:
# 0.6892592592592592

# %% [markdown]
# # Armando el modelo predictivo

# %%
Y_pred = model.predict(E_test)

Y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
DataR = pd.DataFrame(Y_pred, columns=["pred"])
DataR
# Out:
#       pred
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 1995     0
# 1996     0
# 1997     0
# 1998     0
# 1999     0
#
# [2000 rows x 1 columns]

# %%
unique, counts = np.unique(Y_pred, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {0: 1943, 1: 57}

# %%
recall_score(Y_train, Y_pred, average=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [53], line 1
# ----> 1 recall_score(Y_train, Y_pred)
#
# File c:\Users\Mimar\anaconda3\envs\HenryPi\lib\site-packages\sklearn\metrics\_classification.py:1920, in recall_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1789 def recall_score(
#    1790     y_true,
#    1791     y_pred,
#    (...)
#    1797     zero_division="warn",
#    1798 ):
#    1799     """Compute the recall.
#    1800
#    1801     The recall is the ratio ``tp / (tp + fn)`` where ``tp`` is the number of
#    (...)
#    1918     array([1. , 1. , 0.5])
#    1919     """
# -> 1920     _, r, _, _ = precision_recall_fscore_support(
#    1921         y_true,
#    1922         y_pred,
#    1923         labels=labels,
#    1924         pos_label=pos_label,
#    1925         average=average,
#    1926         warn_for=("recall",),
#    1927         sample_weight=sample_weight,
#    1928         zero_division=zero_division,
#    1929     )
#    1930     return r
#
# File c:\Users\Mimar\anaconda3\envs\HenryPi\lib\site-packages\sklearn\metrics\_classification.py:1563, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1561 if beta < 0:
#    1562     raise ValueError("beta should be >=0 in the F-beta score")
# -> 1563 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1565 # Calculate tp_sum, pred_sum, true_sum ###
#    1566 samplewise = average == "samples"
#
# File c:\Users\Mimar\anaconda3\envs\HenryPi\lib\site-packages\sklearn\metrics\_classification.py:1364, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1361 if average not in average_options and average != "binary":
#    1362     raise ValueError("average has to be one of " + str(average_options))
# -> 1364 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1365 # Convert to Python primitive type to avoid NumPy type / Python str
#    1366 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1367 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File c:\Users\Mimar\anaconda3\envs\HenryPi\lib\site-packages\sklearn\metrics\_classification.py:84, in _check_targets(y_true, y_pred)
#      57 def _check_targets(y_true, y_pred):
#      58     """Check that y_true and y_pred belong to the same classification task.
#      59
#      60     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true, input_name="y_true")
#      86     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File c:\Users\Mimar\anaconda3\envs\HenryPi\lib\site-packages\sklearn\utils\validation.py:387, in check_consistent_length(*arrays)
#     385 uniques = np.unique(lengths)
#     386 if len(uniques) > 1:
# --> 387     raise ValueError(
#     388         "Found input variables with inconsistent numbers of samples: %r"
#     389         % [int(l) for l in lengths]
#     390     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [6299, 2000]
